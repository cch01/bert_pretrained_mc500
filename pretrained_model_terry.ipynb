# %% [markdown]
# # Multiple choice question answering script for MC500 data set
# A python script made for MC500, RACE and DREAM data set using pre-trained model `bert-large-uncased-whole-word-masking-finetuned-squad`
#
# ## Libraries needed
# `transformers`, `pytorch`, `pandas`, `sklearn`, `nltk`, `gensim`, `numpy`

# %%
from transformers import BertTokenizer, BertForQuestionAnswering
import torch
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize, sent_tokenize
import numpy as np
import random
import gensim
import os
import pathlib
import json

# %% [markdown]
# ## Preconfigurations for BERT model

# %%
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
if torch.cuda.is_available():
  model.to('cuda')

# %% [markdown]
# ## Read data sets

# %%
def readMcTest(data_path, question_paths, answer_paths):
  
  question_data = pd.concat([pd.read_csv(data_path + _question_path, sep='\t',  names=range(0,23)) for _question_path in question_paths], ignore_index=True, sort=False)
  print('Total question count ', len(question_data))
  
  answer_data = pd.concat([pd.read_csv(data_path + _answer_path, sep='\t',  names=['1','2','3','4']) for _answer_path in answer_paths], ignore_index=True, sort=False)
  print('Total answer count ', len(answer_data))

  passages = list(map(lambda _passage: _passage.replace('\\newline', ' '), question_data[2]))

  questions = question_data[[3,8,13,18]]
  questions.columns=range(0,4)

  options =  question_data[[4,5,6,7, 9,10,11,12,14,15,16,17,19,20,21,22]]
  options.columns = ['1A','1B','1C','1D','2A','2B','2C','2D','3A','3B','3C','3D','4A','4B','4C','4D']

  return (passages, questions, options, answer_data)

# %%
def readDREAM(docPath):
    with open(docPath) as f:
        data = json.load(f)

    dataset = []
    for story in data:
        temp = {}

        # pre-processing of article
        # for sentence spoke by "M:", add prefix "Men:" to every sentence 
        # for sentence spoke by "W:", add prefix "Women:" to every sentence 
        temp["article"] = ""
        for sentence in story[0]:
            if "M:" in sentence:
                sentence = sentence.replace("M: ", "")
                for sent in sent_tokenize(sentence):
                    temp["article"] += "Men: " + sent + " "
            elif "W:" in sentence:
                sentence = sentence.replace("W: ", "")
                for sent in sent_tokenize(sentence):
                    temp["article"] += "Woman: " + sent + " "
            else:
                temp["article"] += sentence

        temp["question"] = story[1][0]["question"]
        for i in range(len(story[1][0]["choice"])):
            temp[f"choice {i}"] = story[1][0]["choice"][i]

        # answer choice = A/B/C/D, answer index = 0/1/2/3, answer = answer in string format
        temp["answer"] = story[1][0]["answer"]
        for i in range(len(story[1][0]["choice"])):
            if story[1][0]["choice"][i] == story[1][0]["answer"]:
                temp["answer choice"] = chr(i + 65)      # from 0 to "A"
                temp["answer index"] = i
                break
        
        dataset.append(temp)

    return pd.DataFrame(dataset)

# %%
def readRACE(relativeDocPath):
    dataset = []

    for filename in os.listdir(os.path.join(os.getcwd(), relativeDocPath)):
        with open(os.path.join(relativeDocPath, filename), 'r') as f: # open in readonly mode
            story = json.load(f)
        
        temp = {}
        temp["article"] = story["article"].replace('\\n', ' ')
        # print(temp["article"])
        tempPerQuestion = {}
        for i in range(len(story["questions"])):
            temp = {"article": temp["article"]}   

            temp["question"] = story["questions"][i]
            for j in range(len(story["options"][i])):
                temp[f"choice {j}"] = story["options"][i][j]
                
            # answer choice = A/B/C/D, answer index = 0/1/2/3, answer = answer in string format
            temp["answer index"] = ord(story["answers"][i]) - 65      # from "A" to 0
            temp["answer"] = temp[f"choice {temp['answer index']}"]
            temp["answer choice"] = story["answers"][i]

            dataset.append(temp)

    return pd.DataFrame(dataset)

# %% [markdown]
# ## Utils

# %% [markdown]
# ### Develop simlarity model

# %%
def similarity_model(ans_str):

  tokenized_docs = list(map(lambda ans: [w.lower() for w in word_tokenize(ans)], ans_str))

  dictionary = gensim.corpora.Dictionary(tokenized_docs)

  corpus = [dictionary.doc2bow(doc) for doc in tokenized_docs]

  tf_idf = gensim.models.TfidfModel(corpus)

  sims = gensim.similarities.docsim.MatrixSimilarity(tf_idf[corpus],num_features=len(dictionary))

  return (dictionary, sims, tf_idf)

# %% [markdown]
# ### Cosine similarity

# %%
def cos_sim(dictionary, sim_model, tf_idf, ans_str):

  query_doc = [w.lower() for w in word_tokenize(ans_str)]

  query_doc_bow = dictionary.doc2bow(query_doc)

  # perform a similarity query against the corpus
  query_doc_tf_idf = tf_idf[query_doc_bow]

  probability = sim_model[query_doc_tf_idf]

  return probability

# %% [markdown]
# ### Pick predicted anwser choice based on probabilities

# %%
def pick_answer_from_probabilities(probabilities, choice_count = 4):
  option_probabilities =  {'A':'','B':'','C':''} if choice_count == 3 else  {'A':'','B':'','C':'', 'D': ''} 

  for opt, proba in zip(option_probabilities.keys(), probabilities):
    option_probabilities[opt] = proba

  print('Probabilities for this question:', option_probabilities)

  max_probability = max(option_probabilities.values())
  if max_probability == 0:
      random_picked_answer = random.choice(['A','B','C'] if choice_count == 3 else ['A','B','C'] )
      print('Random picked option: {}'.format(random_picked_answer))
      return random_picked_answer
  else:
    for key, val in option_probabilities.items(): 
      if val == max_probability:
        print('Predicted option: {}'.format(key))
        return key

# %% [markdown]
# ## Predict answer using the model

# %%
def answer_question(question, text):

  input_ids = tokenizer.encode(question, text, padding=True, truncation=True, max_length=510, add_special_tokens = True)
  sep_index = input_ids.index(tokenizer.sep_token_id)
  num_seg_a = sep_index + 1
  num_seg_b = len(input_ids) - num_seg_a
  segment_ids = [0]*num_seg_a + [1]*num_seg_b

  assert len(segment_ids) == len(input_ids)

  input_tensors = torch.tensor([input_ids]).to('cuda') if torch.cuda.is_available() else torch.tensor([input_ids])
  segment_id_tensors = torch.tensor([segment_ids]).to('cuda') if torch.cuda.is_available() else torch.tensor([segment_ids])
  outputs = model(input_tensors,
                  token_type_ids=segment_id_tensors,
                  return_dict=True) 

  start_scores = outputs.start_logits
  end_scores = outputs.end_logits

  # Find the tokens with the highest `start` and `end` scores.
  answer_start = torch.argmax(start_scores)
  answer_end = torch.argmax(end_scores)

  tokens = tokenizer.convert_ids_to_tokens(input_ids)

  # Answer start with the first token.
  answer = tokens[answer_start]

  for i in range(answer_start + 1, answer_end + 1):
      # If it's a subword token, then recombine it with the previous token.
      if tokens[i][0:2] == '##':
          answer += tokens[i][2:]
      else:
          answer += ' ' + tokens[i]

  return answer

# %% [markdown]
# ## Running MC500 test data set

# %%
  passages, questions, options, answer_data = readMcTest('./data/MCTest/', ['mc500.test.tsv'], ['mc500.test.ans'])

  all_predicted_options = []
  for i in range(len(passages)):
    for q in range(len(questions.loc[i])):
      print('Answering passage no ', str(i), ', question ',str(q+1))

      predicted_answer_string = answer_question(questions.loc[i][q].replace('multiple: ', '').replace('one: ', ''), passages[i])
      print('Predicted answer string: "{}"'.format(predicted_answer_string))

      correct_ans = answer_data.loc[i][q] 
      print('Correct option is '+ correct_ans)

      option_strings = list(map(lambda testing_opt: options.loc[i][str(q+1)+testing_opt], ['A', 'B', 'C', 'D']))
      options_map = {'A': option_strings[0], 'B': option_strings[1], 'C': option_strings[2], 'D': option_strings[3] }

      dictionary, sims, tf_idf = similarity_model(option_strings)

      probabilities = cos_sim(dictionary, sims, tf_idf, predicted_answer_string)
      
      picked_answer = pick_answer_from_probabilities(probabilities)
      print('Answer predicted: "{}"\n'.format(options_map[picked_answer]))

      all_predicted_options.append(picked_answer)

  assert len(all_predicted_options) == len(answer_data.values.flatten().tolist())


  print('Accuracy', accuracy_score(answer_data.values.flatten().tolist(), all_predicted_options))
  print(classification_report(answer_data.values.flatten().tolist(), all_predicted_options))
# Out:
# ion: {'A': 1.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer predicted: "Green"
#
# Answering passage no  132 , question  1
# Predicted answer string: "to see if he can help"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer predicted: "Oil"
#
# Answering passage no  132 , question  2
# Predicted answer string: "a machine that pulls oil out of the earth"
# Correct option is D
# Probabilities for this question: {'A': 0.07856742, 'B': 0.0, 'C': 0.48112524, 'D': 0.80013233}
# Predicted option: D
# Answer predicted: "A pump-jack is a machine that pulls Oil out of the Earth."
#
# Answering passage no  132 , question  3
# Predicted answer string: "very tough time keeping them working"
# Correct option is A
# Probabilities for this question: {'A': 0.78446454, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer predicted: "Keeping his pump-jacks working"
#
# Answering passage no  132 , question  4
# Predicted answer string: "oil"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer predicted: "Oil"
#
# Answering passage no  133 , question  1
# Predicted answer string: "the seed"
# Correct option is A
# Probabilities for this question: {'A': 0.9791394, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer predicted: "A seed."
#
# Answering passage no  133 , question  2
# Predicted answer string: "the fair"
# Correct option is D
# Probabilities for this question: {'A': 0.02949974, 'B': 0.037080806, 'C': 0.0, 'D': 0.89814293}
# Predicted option: D
# Answer predicted: "At the fair."
#
# Answering passage no  133 , question  3
# Predicted answer string: "water"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 1.0, 'D': 0.0}
# Predicted option: C
# Answer predicted: "Water."
#
# Answering passage no  133 , question  4
# Predicted answer string: "fall"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.9791394, 'D': 0.0}
# Predicted option: C
# Answer predicted: "In the fall."
#
# Answering passage no  134 , question  1
# Predicted answer string: "ran around the yard as fast as he could"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.06262243, 'D': 1.0}
# Predicted option: D
# Answer predicted: "He ran around the yard as fast as he could."
#
# Answering passage no  134 , question  2
# Predicted answer string: "ran around the yard as fast as he could . after running , poppy began to play with his ball"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.3733981, 'C': 0.4082483, 'D': 0.0}
# Predicted option: C
# Answer predicted: "He played with Mary."
#
# Answering passage no  134 , question  3
# Predicted answer string: "poppy"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer predicted: "Poppy"
#
# Answering passage no  134 , question  4
# Predicted answer string: "play with his ball"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.70710677, 'D': 0.0}
# Predicted option: C
# Answer predicted: "He played with the ball."
#
# Answering passage no  135 , question  1
# Predicted answer string: "tanner , henry , and ryan"
# Correct option is C
# Probabilities for this question: {'A': 0.57735026, 'B': 0.57735026, 'C': 0.57735026, 'D': 0.0}
# Predicted option: A
# Answer predicted: "Ryan"
#
# Answering passage no  135 , question  2
# Predicted answer string: "dunk it"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.99999994, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer predicted: "Dunk it"
#
# Answering passage no  135 , question  3
# Predicted answer string: "hoopsters"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer predicted: "The Hoopsters"
#
# Answering passage no  135 , question  4
# Predicted answer string: "basketball"
# Correct option is A
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer predicted: "Basketball"
#
# Answering passage no  136 , question  1
# Predicted answer string: "her brother , mark"
# Correct option is A
# Probabilities for this question: {'A': 1.0, 'B': 0.6454972, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer predicted: "Her brother, Mark."
#
# Answering passage no  136 , question  2
# Predicted answer string: "a man"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.61173165, 'C': 0.0, 'D': 0.52806467}
# Predicted option: B
# Answer predicted: "Mark and a man who walked by."
#
# Answering passage no  136 , question  3
# Predicted answer string: "a safe place"
# Correct option is A
# Probabilities for this question: {'A': 0.99289906, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer predicted: "To a safe place."
#
# Answering passage no  136 , question  4
# Predicted answer string: "a huge storm coming . as they were swimming , the life guard told everyone to get out of the pool . the life guard also warned everyone of the storm . jane and mark got out of the pool as fast as they could and went to a safe place and waited until the storm was over"
# Correct option is C
# Probabilities for this question: {'A': 0.295771, 'B': 0.2186382, 'C': 0.68344235, 'D': 0.44549423}
# Predicted option: C
# Answer predicted: "The life guard said to get out because of the storm."
#
# Answering passage no  137 , question  1
# Predicted answer string: "pulled out the prettiest prized purple flowers"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.2264554, 'D': 0.3746343}
# Predicted option: D
# Answer predicted: "She picked purple flowers off of a bush to give to Mrs. Jones"
#
# Answering passage no  137 , question  2
# Predicted answer string: "dirt"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.3086067, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer predicted: "She had dirt on her and her mom said not to get dirty"
#
# Answering passage no  137 , question  3
# Predicted answer string: "we"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer predicted: "Michelle ate pies out of mud"
#
# Answering passage no  137 , question  4
# Predicted answer string: "making pies and cakes out of mud"
# Correct option is C
# Probabilities for this question: {'A': 0.28867513, 'B': 0.0, 'C': 0.46990794, 'D': 0.0}
# Predicted option: C
# Answer predicted: "making pies and cakes and writing their ABCs in the dirt."
#
# Answering passage no  138 , question  1
# Predicted answer string: "her cousin , mary , was coming to visit today"
# Correct option is C
# Probabilities for this question: {'A': 0.050778266, 'B': 0.0, 'C': 0.71594715, 'D': 0.2254769}
# Predicted option: C
# Answer predicted: "Mary was coming to visit today and the new kittens."
#
# Answering passage no  138 , question  2
# Predicted answer string: "the barn"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer predicted: "The kittens are in the barn."
#
# Answering passage no  138 , question  3
# Predicted answer string: "i only want to keep two kittens"
# Correct option is B
# Probabilities for this question: {'A': 0.18894488, 'B': 0.6916141, 'C': 0.0, 'D': 0.010567381}
# Predicted option: B
# Answer predicted: "Six kittens is too many. She only wants to keep two kittens."
#
# Answering passage no  138 , question  4
# Predicted answer string: "cooking breakfast"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.99999994, 'C': 0.19999999, 'D': 0.0}
# Predicted option: B
# Answer predicted: "She is cooking breakfast."
#
# Answering passage no  139 , question  1
# Predicted answer string: "food"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer predicted: "food"
#
# Answering passage no  139 , question  2
# Predicted answer string: "frosting from a cake"
# Correct option is C
# Probabilities for this question: {'A': 0.041286085, 'B': 0.041286085, 'C': 0.9791394, 'D': 0.041286085}
# Predicted option: C
# Answer predicted: "frosting"
#
# Answering passage no  139 , question  3
# Predicted answer string: "a wire"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer predicted: "a wire"
#
# Answering passage no  139 , question  4
# Predicted answer string: "paint from a paint can"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer predicted: "paint from a paint can"
#
# Answering passage no  140 , question  1
# Predicted answer string: "rainbow fish"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer predicted: "rainbow fish"
#
# Answering passage no  140 , question  2
# Predicted answer string: "fish always love to have something to swim in"
# Correct option is D
# Probabilities for this question: {'A': 0.068725266, 'B': 0.009944241, 'C': 0.081967175, 'D': 0.99999994}
# Predicted option: D
# Answer predicted: "Fish always love to have something to swim in."
#
# Answering passage no  140 , question  3
# Predicted answer string: "he wants to learn how to take care of a goldfish"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.99999994, 'D': 0.0}
# Predicted option: C
# Answer predicted: "He wants to learn how to take care of a goldfish."
#
# Answering passage no  140 , question  4
# Predicted answer string: "oceanside"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer predicted: "Oceanside"
#
# Answering passage no  141 , question  1
# Predicted answer string: "a flower"
# Correct option is C
# Probabilities for this question: {'A': 0.034576405, 'B': 0.7346081, 'C': 0.27986038, 'D': 0.0}
# Predicted option: B
# Answer predicted: "Only a flower"
#
# Answering passage no  141 , question  2
# Predicted answer string: "the bedroom"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.43116298}
# Predicted option: D
# Answer predicted: "In the bathroom, kitchen, hallway and bedroom."
#
# Answering passage no  141 , question  3
# Predicted answer string: "butter on to half of the toast . then sue put jam"
# Correct option is A
# Probabilities for this question: {'A': 0.81649655, 'B': 0.24999999, 'C': 0.5, 'D': 0.24999999}
# Predicted option: A
# Answer predicted: "Sue put butter and jam on the toast."
#
# Answering passage no  141 , question  4
# Predicted answer string: "[SEP] sue was going to make her auntie wendy toast . sue got out the bread . sue put the bread in to the toaster . after the bread went pop out of the toaster , sue put butter on to half of the toast . then sue put jam on the other half of the toast . sue got out a tray . sue put the toast on a plate and then put the plate with the toast on to the tray . sue put a flower on to the tray with the toast . sue took the toast to her auntie wendy . auntie wendy was not in the bathroom . sue heard her brother tom"
# Correct option is D
# Probabilities for this question: {'A': 0.54193133, 'B': 0.53369224, 'C': 0.26549104, 'D': 0.70370454}
# Predicted option: D
# Answer predicted: "Sue, Auntie Wendy and Tom"
#
# Answering passage no  142 , question  1
# Predicted answer string: "meat"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.70710677, 'D': 0.4472136}
# Predicted option: C
# Answer predicted: "Meat and Pickle"
#
# Answering passage no  142 , question  2
# Predicted answer string: "tomato"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 1.0, 'D': 0.0}
# Predicted option: C
# Answer predicted: "Tomato"
#
# Answering passage no  142 , question  3
# Predicted answer string: "bread"
# Correct option is D
# Probabilities for this question: {'A': 0.20318978, 'B': 0.0, 'C': 0.20318978, 'D': 0.38333288}
# Predicted option: D
# Answer predicted: "Bread and cheese"
#
# Answering passage no  142 , question  4
# Predicted answer string: "lettuce"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer predicted: "Lettuce"
#
# Answering passage no  143 , question  1
# Predicted answer string: "one hour"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer predicted: "three hours"
#
# Answering passage no  143 , question  2
# Predicted answer string: "wood is popular , but splinters would hurt his son . metal is very strong , but it would also be very hard to use . plastic is not expensive , but it also bends a lot . the last choice was to give up , but albert really wanted to do this for his son . it would make him very happy . albert ended up choosing wood"
# Correct option is C
# Probabilities for this question: {'A': 0.6030227, 'B': 0.21320072, 'C': 0.42640144, 'D': 0.21320072}
# Predicted option: A
# Answer predicted: "Albert chose not to make the tree house"
#
# Answering passage no  143 , question  3
# Predicted answer string: "something big to share with his kid"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer predicted: "A desk"
#
# Answering passage no  143 , question  4
# Predicted answer string: "glue"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer predicted: "Glue"
#
# Answering passage no  144 , question  1
# Predicted answer string: "syrup"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer predicted: "syrup"
#
# Answering passage no  144 , question  2
# Predicted answer string: "a nearby baby started crying ."
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.30151135, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer predicted: "The man pushed the mailman who fell on a teacher which made the baby cry."
#
# Answering passage no  144 , question  3
# Predicted answer string: "his other job"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer predicted: "Eating the pancakes and sweeping the floor."
#
# Answering passage no  144 , question  4
# Predicted answer string: "gum and gloves"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.99999994, 'D': 0.0}
# Predicted option: C
# Answer predicted: "gum and gloves"
#
# Answering passage no  145 , question  1
# Predicted answer string: "it"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer predicted: "She wanted a present for her mom"
#
# Answering passage no  145 , question  2
# Predicted answer string: "her old"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer predicted: "Anna used to sleep in it"
#
# Answering passage no  145 , question  3
# Predicted answer string: "hold him until he is quiet"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 1.0, 'D': 0.0}
# Predicted option: C
# Answer predicted: "Hold him"
#
# Answering passage no  145 , question  4
# Predicted answer string: "all the money she had"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer predicted: "it was free"
#
# Answering passage no  146 , question  1
# Predicted answer string: "he felt curious about why jill was sitting on the phone"
# Correct option is B
# Probabilities for this question: {'A': 0.0074370704, 'B': 0.9865029, 'C': 0.0, 'D': 0.08949422}
# Predicted option: B
# Answer predicted: "Because he was curious about why Jill was sitting on the phone."
#
# Answering passage no  146 , question  2
# Predicted answer string: "he looked behind him and saw a forest and a big volcano"
# Correct option is A
# Probabilities for this question: {'A': 0.31815538, 'B': 0.3812688, 'C': 0.0, 'D': 0.2519763}
# Predicted option: B
# Answer predicted: "Jumped into the volcano."
#
# Answering passage no  146 , question  3
# Predicted answer string: "flew from the flower to a telephone down the block . he followed jill and watched her land on the phone"
# Correct option is C
# Probabilities for this question: {'A': 0.10546418, 'B': 0.0, 'C': 0.9029272, 'D': 0.23651916}
# Predicted option: C
# Answer predicted: "Flew from the flower to the telephone."
#
# Answering passage no  146 , question  4
# Predicted answer string: "john"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer predicted: "John"
#
# Answering passage no  147 , question  1
# Predicted answer string: "panda"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 1.0, 'D': 0.0}
# Predicted option: C
# Answer predicted: "Panda"
#
# Answering passage no  147 , question  2
# Predicted answer string: "leaves"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer predicted: "Leaves."
#
# Answering passage no  147 , question  3
# Predicted answer string: "bathe and climb trees"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.99999994, 'D': 0.0}
# Predicted option: C
# Answer predicted: "Climb trees."
#
# Answering passage no  147 , question  4
# Predicted answer string: "panda"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer predicted: "Larry's"
#
# Answering passage no  148 , question  1
# Predicted answer string: "saturday"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 1.0, 'D': 0.0}
# Predicted option: C
# Answer predicted: "Saturday"
#
# Answering passage no  148 , question  2
# Predicted answer string: "8"
# Correct option is A
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer predicted: "8"
#
# Answering passage no  148 , question  3
# Predicted answer string: "helped them put the wheels on the racing car"
# Correct option is A
# Probabilities for this question: {'A': 0.8462622, 'B': 0.10478221, 'C': 0.072365545, 'D': 0.29948187}
# Predicted option: A
# Answer predicted: "He helped put the wheels on."
#
# Answering passage no  148 , question  4
# Predicted answer string: "on the track at his school"
# Correct option is B
# Probabilities for this question: {'A': 0.36369652, 'B': 0.8095238, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer predicted: "On the track near his school."
#
# Answering passage no  149 , question  1
# Predicted answer string: "sam , mark and david"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.6324555, 'C': 0.47140452, 'D': 0.0}
# Predicted option: B
# Answer predicted: "Mark, nobody"
#
# Answering passage no  149 , question  2
# Predicted answer string: "coffee"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer predicted: "Coffee store"
#
# Answering passage no  149 , question  3
# Predicted answer string: "his home team winning by one"
# Correct option is D
# Probabilities for this question: {'A': 0.3970095, 'B': 0.40824828, 'C': 0.0, 'D': 0.794019}
# Predicted option: D
# Answer predicted: "Home team, by one run."
#
# Answering passage no  149 , question  4
# Predicted answer string: "marshmallow and chocolate cake"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer predicted: "Marshmallow and chocolate cake"
#
# Accuracy 0.7283333333333334
#               precision    recall  f1-score   support
#
#            A       0.70      0.72      0.71       141
#            B       0.71      0.75      0.73       146
#            C       0.67      0.69      0.68       145
#            D       0.85      0.75      0.79       168
#
#     accuracy                           0.73       600
#    macro avg       0.73      0.73      0.73       600
# weighted avg       0.73      0.73      0.73       600

# %% [markdown]
# ## Running RACE middle test data set

# %%
  race_data = readRACE('./data/RACE/test/middle')

  all_predicted_options = []
  for i in range(len(race_data)):
    predicted_answer_string = answer_question(race_data['question'][i], race_data['article'][i])
    print('Predicted answer string: "{}"'.format(predicted_answer_string))

    correct_ans = race_data['answer choice'][i]
    print('Correct option is '+ correct_ans)

    option_strings = list(map(lambda choice: race_data.loc[i][choice], ['choice 0', 'choice 1', 'choice 2', 'choice 3']))
    options_map = {'A': option_strings[0], 'B': option_strings[1], 'C': option_strings[2], 'D': option_strings[3] }

    dictionary, sims, tf_idf = similarity_model(option_strings)

    probabilities = cos_sim(dictionary, sims, tf_idf, predicted_answer_string)
    
    picked_answer = pick_answer_from_probabilities(probabilities)
    print('Answer precited: "{}"\n'.format(options_map[picked_answer]))
    
    all_predicted_options.append(picked_answer)


  assert len(all_predicted_options) == len(race_data)

  print('Accuracy', accuracy_score(race_data['answer choice'], all_predicted_options))
  print(classification_report(race_data['answer choice'], all_predicted_options))
# Out:
#  'B': 0.0, 'C': 0.0, 'D': 0.67936623}
# Predicted option: D
# Answer precited: "Because Poor wanted the writer to pay for the dinner."
#
# Predicted answer string: "read"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "Poor is an old man"
#
# Predicted answer string: "if you don ' t make money , no one is going to give it to you"
# Correct option is A
# Probabilities for this question: {'A': 0.41305107, 'B': 0.039561987, 'C': 0.039561987, 'D': 0.029974544}
# Predicted option: A
# Answer precited: "they make a living by driving"
#
# Predicted answer string: "not only " take " but also " give " ."
# Correct option is C
# Probabilities for this question: {'A': 0.28623122, 'B': 0.23776507, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "They give the poor children a lunch party at the sea each summer."
#
# Predicted answer string: "" take " but also " give ""
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "Rich and generous"
#
# Predicted answer string: "[CLS]"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "a website about the taxi drivers in London"
#
# Predicted answer string: "waiting for the no . 6 bus . they want to buy some new books"
# Correct option is B
# Probabilities for this question: {'A': 0.25156873, 'B': 1.0, 'C': 0.051588178, 'D': 0.0}
# Predicted option: B
# Answer precited: "They are waiting for the bus."
#
# Predicted answer string: "buy some new books"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "They might go to the zoo."
#
# Predicted answer string: "a thief"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.99999994, 'C': 0.19999999, 'D': 0.0}
# Predicted option: B
# Answer precited: "a thief"
#
# Predicted answer string: "filming a movie"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "policemen"
#
# Predicted answer string: "two"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "Jim and Andy want to be actors"
#
# Predicted answer string: "13"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer precited: "13."
#
# Predicted answer string: "."
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "at noon"
#
# Predicted answer string: "delivering newspapers"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.70710677}
# Predicted option: D
# Answer precited: "deliver newspapers"
#
# Predicted answer string: "12"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "17."
#
# Predicted answer string: "rockets"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer precited: "rockets"
#
# Predicted answer string: "a glove"
# Correct option is C
# Probabilities for this question: {'A': 0.041286085, 'B': 0.0, 'C': 1.0, 'D': 0.020970263}
# Predicted option: C
# Answer precited: "a glove"
#
# Predicted answer string: "28 , 000"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "300,000"
#
# Predicted answer string: "fast"
# Correct option is A
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "fast"
#
# Predicted answer string: "dangerous"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer precited: "dangerous"
#
# Predicted answer string: "poor"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "eat breakfast every morning"
#
# Predicted answer string: "meet friends"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.48507124, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer precited: "make something with your friends"
#
# Predicted answer string: "eat"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "All the traffic accidents are caused by poor sleep."
#
# Predicted answer string: "[CLS]"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "students who never have breakfast"
#
# Predicted answer string: "[CLS]"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "Ways to Improve Your Health"
#
# Predicted answer string: "you play volleyball well . but your pe teacher doesn ' t like fat girls"
# Correct option is B
# Probabilities for this question: {'A': 0.2662614, 'B': 0.01048538, 'C': 0.38216704, 'D': 0.011582031}
# Predicted option: C
# Answer precited: "Because her PE teacher likes her very much."
#
# Predicted answer string: "the best volleyball player in our class"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.5}
# Predicted option: D
# Answer precited: "A good basketball player."
#
# Predicted answer string: "go"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.5}
# Predicted option: D
# Answer precited: "go running every day"
#
# Predicted answer string: "our pe teacher says i can ' t get into the team . he says i am too fat . i really want to be a good volleyball player . this is my dream . can you help me ? jane dear jane , i ' m sorry to know that you ' re not happy . you play volleyball well . but your pe teacher doesn ' t like fat girls"
# Correct option is C
# Probabilities for this question: {'A': 0.37543416, 'B': 0.22120051, 'C': 0.6011046, 'D': 0.32566094}
# Predicted option: C
# Answer precited: "Jane's PE teacher doesn't like fat girls."
#
# Predicted answer string: "central hangzhou"
# Correct option is A
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "in central Hangzhou"
#
# Predicted answer string: "three causeways called su di , bai di , and yanggong di"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer precited: "three"
#
# Predicted answer string: "first"
# Correct option is A
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "first"
#
# Predicted answer string: "[CLS] the above words are probably for _ . [SEP]"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "teachers"
#
# Predicted answer string: "amazed"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 1.0, 'D': 0.0}
# Predicted option: C
# Answer precited: "Amazed."
#
# Predicted answer string: "not healthy"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "interesting and cheap"
#
# Predicted answer string: "seven"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer precited: "Seven."
#
# Predicted answer string: "[CLS] we can most probably read the passage in a magazine about _ . [SEP]"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "news"
#
# Predicted answer string: "[CLS] what is the best title for the passage ? [SEP]"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.5}
# Predicted option: D
# Answer precited: "What to bring to school."
#
# Predicted answer string: "my"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "sold many story books"
#
# Predicted answer string: "imagination had plenty of space to expand"
# Correct option is A
# Probabilities for this question: {'A': 0.6666666, 'B': 0.0, 'C': 0.3333333, 'D': 0.0}
# Predicted option: A
# Answer precited: "expand his imagination"
#
# Predicted answer string: "twelve"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "22"
#
# Predicted answer string: "steve"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "hens, rabbits and dogs"
#
# Predicted answer string: "steve"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "likes eating Japanese and Indian food"
#
# Predicted answer string: "all this is natural"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.37796447}
# Predicted option: D
# Answer precited: "Because she is not good enough at school."
#
# Predicted answer string: "i ' m not allowed to stay out as late"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "less freedom"
#
# Predicted answer string: "try"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "Be different from other teenagers."
#
# Predicted answer string: "you"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "Angel's father likes the music that Angel likes."
#
# Predicted answer string: "one or two"
# Correct option is D
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "Two."
#
# Predicted answer string: "still using energy"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "It will save a lot of oil that runs your car for a mile."
#
# Predicted answer string: "way 3 : reuse plastic bags"
# Correct option is A
# Probabilities for this question: {'A': 0.38333288, 'B': 0.38333288, 'C': 0.20318978, 'D': 0.0}
# Predicted option: A
# Answer precited: "Ways 3 & 4."
#
# Predicted answer string: "just one tree will help make cleaner air and save the environment from 5 , 000 pounds of hot co each year"
# Correct option is C
# Probabilities for this question: {'A': 0.25354627, 'B': 0.3023716, 'C': 0.0, 'D': 0.41239306}
# Predicted option: D
# Answer precited: "They all help protect our trees and forests."
#
# Predicted answer string: "help make cleaner air and save the environment from 5 , 000 pounds of hot co each year"
# Correct option is D
# Probabilities for this question: {'A': 0.05510613, 'B': 0.7163797, 'C': 0.55969185, 'D': 0.2309401}
# Predicted option: B
# Answer precited: "To help make cleaner air"
#
# Predicted answer string: "emily urich"
# Correct option is C
# Probabilities for this question: {'A': 0.6784916, 'B': 0.0, 'C': 0.8119707, 'D': 0.0}
# Predicted option: C
# Answer precited: "Emily and An Qi."
#
# Predicted answer string: "cartoon book was on my third birthday . from then on , i fell in deep love with it . and can you guess how many cartoon books i ' ve read ? i don ' t really know the exact number . but i have three full boxes of them under my bed . i also like drawing cartoons"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "Skiing."
#
# Predicted answer string: "[CLS]"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "she laughs at other people"
#
# Predicted answer string: "[CLS]"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "thinks skiing is too dangerous"
#
# Predicted answer string: "hope project"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "Because her parents are teachers."
#
# Predicted answer string: "where there are cool colours"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.40824828, 'D': 0.40824828}
# Predicted option: C
# Answer precited: "prefer warm colours"
#
# Predicted answer string: "warm colours can produce a comfortable feeling and that time seems to pass quickly in a room with warm colours than with cool colours"
# Correct option is C
# Probabilities for this question: {'A': 0.4218814, 'B': 0.5049177, 'C': 0.1657104, 'D': 0.30951303}
# Predicted option: B
# Answer precited: "Time seems to pass more slowly in a red room than in a violet room."
#
# Predicted answer string: "it can make people who are working feel relaxed and calm"
# Correct option is D
# Probabilities for this question: {'A': 0.19996043, 'B': 0.09158406, 'C': 0.0, 'D': 0.82961047}
# Predicted option: D
# Answer precited: "Because people who are working can be more relaxed and calm."
#
# Predicted answer string: "[SEP]"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "People and colours"
#
# Predicted answer string: "responsibility , independence , teamwork and leadership"
# Correct option is D
# Probabilities for this question: {'A': 0.57735026, 'B': 0.57735026, 'C': 0.57735026, 'D': 0.0}
# Predicted option: A
# Answer precited: "responsibility"
#
# Predicted answer string: "14"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "twelve"
#
# Predicted answer string: "camps , swimming pools and amusement parks"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "At a camp."
#
# Predicted answer string: "work experience and the skills they gain on the job"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "like to play with children"
#
# Predicted answer string: "12"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "five"
#
# Predicted answer string: "$ 2 . 00"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "$3.00"
#
# Predicted answer string: "9 : 00a . m - - 4 : 00p . m"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "8:30am Monday"
#
# Predicted answer string: "giraffes from brazil"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "long"
#
# Predicted answer string: "keep the zoo clean ! don ' t touch , give good food or go near the animals"
# Correct option is D
# Probabilities for this question: {'A': 0.41760308, 'B': 0.23100165, 'C': 0.0, 'D': 0.7120926}
# Predicted option: D
# Answer precited: "to keep the zoo clean"
#
# Predicted answer string: "[CLS]"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "how to make clothes"
#
# Predicted answer string: "discs or old clothes"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "cotton"
#
# Predicted answer string: "discs"
# Correct option is D
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "discs"
#
# Predicted answer string: "the show gave the students a chance to make things with their own hands"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.5669467, 'D': 0.2236068}
# Predicted option: C
# Answer precited: "how to make use of old things"
#
# Predicted answer string: "mickey mouse is a clean mouse"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "England"
#
# Predicted answer string: "walt disney"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.9252661, 'D': 0.0}
# Predicted option: C
# Answer precited: "A man named Walt Disney"
#
# Predicted answer string: "he makes them happy and _ . in the film , mickey mouse also has a lot of friends , for example , donald duck and pluto . donald can do many things that mickey cannot . pluto is a dog . he always does foolish things and makes foolish mistakes . many children like these cartoon animals , but they like mickey most because the mouse is a star of beauty and wisdom ."
# Correct option is C
# Probabilities for this question: {'A': 0.2611165, 'B': 0.6908493, 'C': 0.3290726, 'D': 0.38138503}
# Predicted option: B
# Answer precited: "He is like a real mouse."
#
# Predicted answer string: "pluto"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "smart"
#
# Predicted answer string: "the"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "Because he liked washing apples."
#
# Predicted answer string: "his father came back with some apples . the boy liked apples very much and wanted to eat some of them . his mother gave him four apples and said , " go and wash them . " val washed the apples and then gave them back to his mother . mother asked , " which apple do you want , val ? " " the biggest one , mum"
# Correct option is D
# Probabilities for this question: {'A': 0.8077611, 'B': 0.29148656, 'C': 0.033349294, 'D': 0.5272738}
# Predicted option: A
# Answer precited: "His mother."
#
# Predicted answer string: "the biggest one , mum . " " what ? " said his mother , " you should be polite and want the smallest one"
# Correct option is C
# Probabilities for this question: {'A': 0.24618298, 'B': 0.46291006, 'C': 0.15430336, 'D': 0.0}
# Predicted option: B
# Answer precited: "Mother was cooking in the kitchen."
#
# Predicted answer string: "bruce"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 1.0, 'D': 0.0}
# Predicted option: C
# Answer precited: "Bruce"
#
# Predicted answer string: "we like hamburgers for lunch"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "David and Mark"
#
# Predicted answer string: "i"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "David"
#
# Predicted answer string: "i don ' t like eggs for breakfast"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "Mark"
#
# Predicted answer string: "we really like chicken and salad for dinner"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "David and Mark"
#
# Accuracy 0.4296657381615599
#               precision    recall  f1-score   support
#
#            A       0.37      0.48      0.42       309
#            B       0.44      0.46      0.45       388
#            C       0.42      0.47      0.44       374
#            D       0.55      0.31      0.39       365
#
#     accuracy                           0.43      1436
#    macro avg       0.44      0.43      0.43      1436
# weighted avg       0.45      0.43      0.43      1436

# %% [markdown]
# ## Running RACE high test data set

# %%
  race_data = readRACE('./data/RACE/test/high')

  all_predicted_options = []
  for i in range(len(race_data)):
    predicted_answer_string = answer_question(race_data['question'][i], race_data['article'][i])
    print('Predicted answer string: "{}"'.format(predicted_answer_string))

    correct_ans = race_data['answer choice'][i]
    print('Correct option is '+ correct_ans)

    option_strings = list(map(lambda choice: race_data.loc[i][choice], ['choice 0', 'choice 1', 'choice 2', 'choice 3']))
    options_map = {'A': option_strings[0], 'B': option_strings[1], 'C': option_strings[2], 'D': option_strings[3] }

    dictionary, sims, tf_idf = similarity_model(option_strings)

    probabilities = cos_sim(dictionary, sims, tf_idf, predicted_answer_string)
    
    picked_answer = pick_answer_from_probabilities(probabilities)
    print('Answer precited: "{}"\n'.format(options_map[picked_answer]))
    
    all_predicted_options.append(picked_answer)


  assert len(all_predicted_options) == len(race_data)

  print('Accuracy', accuracy_score(race_data['answer choice'], all_predicted_options))
  print(classification_report(race_data['answer choice'], all_predicted_options))
# Out:
# answer string: "[CLS]"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "Benefits of Sunflower Oil for Skin"
#
# Predicted answer string: "[CLS]"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "To explain what caused the explosion of NASA-s unmanned rocket."
#
# Predicted answer string: "really feel sorry for my students"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "Frustrated."
#
# Predicted answer string: "astronauts at the iss felt a more urgent disappointment"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "interesting"
#
# Predicted answer string: "" astronauts on board the iss already drink water distilled from sweat and urine"
# Correct option is D
# Probabilities for this question: {'A': 0.2491177, 'B': 0.0, 'C': 0.3959238, 'D': 0.1883413}
# Predicted option: C
# Answer precited: "The water that astronauts at the ISS drink is mainly made by recycling."
#
# Predicted answer string: "[CLS] this passage is mainly talking about _ . [SEP]"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "a new term "phubbing"and its problem"
#
# Predicted answer string: "[CLS]"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "reasonable"
#
# Predicted answer string: "phubbing is a blend of phone and snubbing"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.36410454, 'D': 0.0}
# Predicted option: C
# Answer precited: "More and more people have become phubbers."
#
# Predicted answer string: "be more kind"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.21320072, 'C': 0.19931452, 'D': 0.0}
# Predicted option: B
# Answer precited: "not be afraid of the harmful effect"
#
# Predicted answer string: "intergovernmental panel on climate change"
# Correct option is A
# Probabilities for this question: {'A': 0.37139067, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "engages in the climate and changes about the earth."
#
# Predicted answer string: "[SEP]"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "is one of the most important greenhouse gases"
#
# Predicted answer string: "a"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "What Are the Scientific Disagreements"
#
# Predicted answer string: "most"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "Objective."
#
# Predicted answer string: "[CLS]"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "Kids are unable to understand lots of exciting information."
#
# Predicted answer string: "[CLS]"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "children's literature"
#
# Predicted answer string: "provides friendship and fun"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.64888567, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer precited: "To provide partnership and fun for young people."
#
# Predicted answer string: "[CLS]"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "24 hours"
#
# Predicted answer string: "providing different feedback about herself"
# Correct option is A
# Probabilities for this question: {'A': 0.57735026, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "a new way to assess herself"
#
# Predicted answer string: "sometimes it ' s all work and no play"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "She felt a bit bored with her life."
#
# Predicted answer string: "there were no other guests"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.39223227, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer precited: "There was an empty place at the table."
#
# Predicted answer string: "the man in the photo"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.4472136, 'D': 0.0}
# Predicted option: C
# Answer precited: "A friend of the family."
#
# Predicted answer string: "it was the man in the photo"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "Upset."
#
# Predicted answer string: "[CLS]"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "Catherine's father got lost on the sea."
#
# Predicted answer string: "lower prices have failed to end the food crisis in many poor countries"
# Correct option is C
# Probabilities for this question: {'A': 0.18402164, 'B': 0.0, 'C': 0.22798038, 'D': 0.30016166}
# Predicted option: D
# Answer precited: "people in developing countries will never get enough food"
#
# Predicted answer string: "growth in agricultural production"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 1.0}
# Predicted option: D
# Answer precited: "the growth in agricultural production"
#
# Predicted answer string: "south asia and central asia"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "Thailand"
#
# Predicted answer string: "" getting enough food every day to live an active and healthy life is a distant dream . ""
# Correct option is C
# Probabilities for this question: {'A': 0.033944327, 'B': 0.0, 'C': 0.033944327, 'D': 0.56280166}
# Predicted option: D
# Answer precited: "The solution to the global food shortage"
#
# Predicted answer string: "sending out the formal printed invitation cards"
# Correct option is C
# Probabilities for this question: {'A': 0.47140452, 'B': 0.23570226, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "make all the arrangements for the wedding"
#
# Predicted answer string: "less usual"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.35821673, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer precited: "It is less usual for guests to attend the civil wedding formalities."
#
# Predicted answer string: "when there are few guests"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.21155074, 'C': 0.0, 'D': 0.24011481}
# Predicted option: D
# Answer precited: "there is to be no party afterwards."
#
# Predicted answer string: "the bride goes off to change into everyday clothes and then leaves the party with her husband to go on their honeymoon , the journey they will make together , often in romantic surrounding abroad ."
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.24618298, 'C': 0.0, 'D': 0.24999999}
# Predicted option: D
# Answer precited: "as soon as the bride is ready"
#
# Predicted answer string: "spain"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "improve the skills to communicate with Teresa"
#
# Predicted answer string: "[CLS] what is the best title for this passage ? [SEP]"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "Getting Better Culture"
#
# Predicted answer string: "popular practices that are storming the world ' s youth on this v - day"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.19183911, 'D': 0.18514629}
# Predicted option: C
# Answer precited: "All the parties are aimed at strangers who want to be lovers."
#
# Predicted answer string: "speed dating"
# Correct option is A
# Probabilities for this question: {'A': 0.99999994, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "Speed dating."
#
# Predicted answer string: "[CLS]"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "you have to eat with your hands"
#
# Predicted answer string: "the more messages you leave on the bulletin board , the more chances you have of winning prizes"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "2."
#
# Predicted answer string: "me and the kids"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "People who like traditional American food"
#
# Predicted answer string: "there are no tables"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.4472136}
# Predicted option: D
# Answer precited: "Customers eating happily around tables"
#
# Predicted answer string: "$ 4 . 75"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "$5.25"
#
# Predicted answer string: "sandwiches"
# Correct option is A
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "sandwiches"
#
# Predicted answer string: "[CLS] we can infer from the passage that the writer _ . [SEP]"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.34815532, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer precited: "feels very happy that be has found Frigo's"
#
# Predicted answer string: "[CLS]"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "babies can tighten their eyelids in response to the sound"
#
# Predicted answer string: "[SEP]"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "babies were born to help others"
#
# Predicted answer string: "[CLS] the writer suggests that the third most common blood type among the europeans is _ . [SEP] when we donate blood , a small amount is usually taken in advance for at least abo and rh systems typing . if you are o + , the o is your abo type and the + is your rh type . it is possible to be a , b , ab , or o as well as rh + or rh - . the abo system was discovered by karl landsteiner in the early 1900s . he was awarded the nobel prize for his achievements . there are four basic types of blood in the abo system : a , b , ab and o . everybody is born with one of these four types of blood . we get blood type , just like hair color and height from parents . because of the substances contained in each type , the four groups must be _ carefully , if two different blood types are mixed together , it may put a person into an extremely dangerous situation . basically , a and b cannot be mixed . a and b cannot receive ab , but ab may receive a or b . in an emergency , type o blood can be given because it is most likely to be accepted by all blood types , so it is often called the universal donor . however , there is still a risk . for the opposite reason , ab is sometimes called the universal receiver . however , because there can be so many reactions in the blood bank of the hospital . there is a relationship between your blood type and your nationality . among the europeans , about 45 percent have type o while 42 percent have type a . the least common is type ab"
# Correct option is A
# Probabilities for this question: {'A': 0.35623524, 'B': 0.7124705, 'C': 0.4274823, 'D': 0.4274823}
# Predicted option: B
# Answer precited: "A"
#
# Predicted answer string: "[CLS]"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "about the basic types of human blood"
#
# Predicted answer string: "back"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.70710677}
# Predicted option: D
# Answer precited: "at the back"
#
# Predicted answer string: "where they can ' t see other passengers"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.37796447, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer precited: "Because they can have a view of everyone else."
#
# Predicted answer string: "coaches"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "buy eco-friendly products in the Castle Shop"
#
# Predicted answer string: "saturday 16th to monday 25th august"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "10 days"
#
# Predicted answer string: "the main town car park that is opposite the castle entrance"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.1367513, 'C': 0.81995475, 'D': 0.4601467}
# Predicted option: C
# Answer precited: "In the main town car park"
#
# Predicted answer string: "[CLS]"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "couldn't eat by himself"
#
# Predicted answer string: "[CLS]"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "decided to have dinner together with her family"
#
# Predicted answer string: "it will become smaller , but faster and more powerful"
# Correct option is D
# Probabilities for this question: {'A': 0.4472136, 'B': 0.4472136, 'C': 0.70710677, 'D': 0.0}
# Predicted option: C
# Answer precited: "More powerful."
#
# Predicted answer string: "quantum"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "has been put in use so far"
#
# Predicted answer string: "nanotechnology could also change the face of computing"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.8614009, 'D': 0.0}
# Predicted option: C
# Answer precited: "change the structure of computers"
#
# Predicted answer string: "[CLS]"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "what nanotechnology is"
#
# Predicted answer string: "18th november"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.5, 'C': 0.0, 'D': 0.0}
# Predicted option: B
# Answer precited: "On 14th November 1963 ."
#
# Predicted answer string: "a"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.30151135, 'D': 0.2182179}
# Predicted option: C
# Answer precited: "A Captain and An Island ."
#
# Predicted answer string: "[CLS] which of the following could not be used to describe the author ' s father ? [SEP]"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "Sympathetic and open-minded."
#
# Predicted answer string: "[CLS] what can we infer about the author ? [SEP]"
# Correct option is D
# Probabilities for this question: {'A': 0.19546969, 'B': 0.0, 'C': 0.0, 'D': 0.2}
# Predicted option: D
# Answer precited: "She felt pity for those children without the father."
#
# Predicted answer string: "to test his people , who had come from all over india , about their values of life"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.023085423, 'C': 0.6621261, 'D': 0.020750409}
# Predicted option: C
# Answer precited: "He wanted to enrich his employees' life."
#
# Predicted answer string: "he did not cheat me or himself"
# Correct option is D
# Probabilities for this question: {'A': 0.5196398, 'B': 0.13904648, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "he didn't take good care of his seed"
#
# Predicted answer string: "the seeds i gave you were boiled seeds"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.4364358, 'D': 0.0}
# Predicted option: C
# Answer precited: "They didn't know why the manager gave him the best seed."
#
# Predicted answer string: "[CLS] the author wanted to tell us the importance of _ by writing this passage . [SEP] once a general manager wanted to test his people , who had come from all over india , about their values of life ."
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.15430336, 'D': 0.7378648}
# Predicted option: D
# Answer precited: "knowing how to please the manager"
#
# Predicted answer string: "[CLS]"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "Plans after Graduation"
#
# Predicted answer string: "you might want to take a year off to pause and regroup . this practice is common in some countries , like the united kingdom"
# Correct option is B
# Probabilities for this question: {'A': 0.08377078, 'B': 0.88040876, 'C': 0.054073807, 'D': 0.048911598}
# Predicted option: B
# Answer precited: "taking a year off to pause and regroup"
#
# Predicted answer string: "pay"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "You'll learn some great life skills."
#
# Predicted answer string: "[CLS]"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "Chai started making the documentary after she gave birth to a daughter."
#
# Predicted answer string: "her " personal clashes " with smog after she gave birth to a daughter"
# Correct option is A
# Probabilities for this question: {'A': 0.6324555, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Predicted option: A
# Answer precited: "She wanted to do something for her daughter"
#
# Predicted answer string: "[CLS]"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: C
# Answer precited: "negative"
#
# Predicted answer string: "throwing"
# Correct option is D
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "dancing along the beach"
#
# Predicted answer string: "[CLS]"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "how and where we can write a good article"
#
# Predicted answer string: "we ' re not playing god here ; we ' re just making sure that two parents who want a healthy baby can have one"
# Correct option is C
# Probabilities for this question: {'A': 0.51065403, 'B': 0.17338374, 'C': 0.1611339, 'D': 0.03217447}
# Predicted option: A
# Answer precited: "The new technique is intended to provide the parents a healthy baby."
#
# Predicted answer string: "[CLS]"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: B
# Answer precited: "DNA of Mitochondria can affect a person's appearance"
#
# Predicted answer string: "making sure that two parents who want a healthy baby can have one"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0, 'D': 0.0}
# Random picked option: A
# Answer precited: "is in favour of"
#
# Accuracy 0.31989708404802747
#               precision    recall  f1-score   support
#
#            A       0.26      0.36      0.30       754
#            B       0.32      0.36      0.34       935
#            C       0.35      0.36      0.36       950
#            D       0.39      0.20      0.27       859
#
#     accuracy                           0.32      3498
#    macro avg       0.33      0.32      0.32      3498
# weighted avg       0.33      0.32      0.32      3498

# %% [markdown]
# ## Running DREAM test data set

# %%
  dream_data = readDREAM('./data/DREAM/test.json')

  all_predicted_options = []
  for i in range(len(dream_data)):
    predicted_answer_string = answer_question(dream_data['question'][i], dream_data['article'][i])
    print('Predicted answer string: "{}"'.format(predicted_answer_string))

    correct_ans = dream_data['answer choice'][i]
    print('Correct option is '+ correct_ans)
    option_strings = list(map(lambda choice: dream_data.loc[i][choice], ['choice 0', 'choice 1', 'choice 2']))
    options_map = {'A': option_strings[0], 'B': option_strings[1], 'C': option_strings[2] }

    dictionary, sims, tf_idf = similarity_model(option_strings)

    probabilities = cos_sim(dictionary, sims, tf_idf, predicted_answer_string)
    
    picked_answer = pick_answer_from_probabilities(probabilities, choice_count = 3)
    print('Answer precited: "{}"\n'.format(options_map[picked_answer]))
    
    all_predicted_options.append(picked_answer)


  assert len(all_predicted_options) == len(dream_data)

  print('Accuracy', accuracy_score(dream_data['answer choice'], all_predicted_options))
  print(classification_report(dream_data['answer choice'], all_predicted_options))
# Out:
# abilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "Come to a meeting."
#
# Predicted answer string: "men : hi , janet , i hear you ' ve just returned from a tour of australia"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.42640144}
# Predicted option: C
# Answer precited: "Janet thinks it's a shame for anyone not to visit Australia."
#
# Predicted answer string: "see my parents first"
# Correct option is B
# Probabilities for this question: {'A': 0.57735026, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "To visit his parents."
#
# Predicted answer string: "in the teachers ' office this afternoon"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "3:30."
#
# Predicted answer string: "men"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "He is busy."
#
# Predicted answer string: "not really . woman : you can just leave a note"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.16582629, 'C': 0.19602434}
# Predicted option: C
# Answer precited: "The man can come back sometime later."
#
# Predicted answer string: "i just feel like a fish out of water"
# Correct option is B
# Probabilities for this question: {'A': 0.5, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "She doesn't like fishing."
#
# Predicted answer string: "eight thirty"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: B
# Answer precited: "8:50"
#
# Predicted answer string: "my sister"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.57735026, 'C': 0.3271846}
# Predicted option: B
# Answer precited: "The man's sister."
#
# Predicted answer string: "$ 7"
# Correct option is A
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "$7."
#
# Predicted answer string: "men : it ' s much quiet"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.4082483, 'C': 0.0}
# Predicted option: B
# Answer precited: "The woman should stay out until the neighbors are quiet."
#
# Predicted answer string: "give it up"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: B
# Answer precited: "Find another job."
#
# Predicted answer string: "his ticket ' s ready"
# Correct option is B
# Probabilities for this question: {'A': 0.57735026, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "He has lost his ticket."
#
# Predicted answer string: "business"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "at the school's library"
#
# Predicted answer string: "men : it ' s a bit difficult"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "The woman can be off on Friday."
#
# Predicted answer string: "men : in just three weeks . men : and i ' m excited ! men : but there are still a few things i need to do before i go ."
# Correct option is B
# Probabilities for this question: {'A': 0.4718749, 'B': 0.23268236, 'C': 0.5092828}
# Predicted option: C
# Answer precited: "The woman is leaving for Europe in just three weeks."
#
# Predicted answer string: "men : we don ' t have the resources to stop those people from buying us out unless a miracle happens . men : this may be the end of us"
# Correct option is A
# Probabilities for this question: {'A': 0.13250731, 'B': 0.16080455, 'C': 0.50837076}
# Predicted option: C
# Answer precited: "They want to borrow a huge sum from the bank."
#
# Predicted answer string: "megan jones"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 1.0}
# Predicted option: C
# Answer precited: "Megan"
#
# Predicted answer string: "men : do you have reason that your wallet was stolen"
# Correct option is C
# Probabilities for this question: {'A': 0.08261894, 'B': 0.05047837, 'C': 0.93623626}
# Predicted option: C
# Answer precited: "Her drawer was stolen."
#
# Predicted answer string: "men : i must have turned the alarm clock off and gone back to sleep again"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "Wife and husband."
#
# Predicted answer string: "can you and tom come"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "Yes, certainly."
#
# Predicted answer string: "i hate this class ."
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "There is no water."
#
# Predicted answer string: "three"
# Correct option is A
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "Three."
#
# Predicted answer string: "men"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "Maybe."
#
# Predicted answer string: "men : if you don ' t like the blue hat , take the red one . woman"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "In a post office."
#
# Predicted answer string: "this week"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "On Monday."
#
# Predicted answer string: "ten minutes"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: B
# Answer precited: "5 minutes."
#
# Predicted answer string: "out"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "To the post office."
#
# Predicted answer string: "a life of continuous exploration is a life worth living"
# Correct option is B
# Probabilities for this question: {'A': 0.14284864, 'B': 0.73401827, 'C': 0.018092688}
# Predicted option: B
# Answer precited: "She prefers a life of continued exploration."
#
# Predicted answer string: "neither do i"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: B
# Answer precited: "She agrees with the man."
#
# Predicted answer string: "one dollar"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "$ 20."
#
# Predicted answer string: "men : i ' d like to open a checking account , please . woman"
# Correct option is C
# Probabilities for this question: {'A': 0.6418712, 'B': 0.0874311, 'C': 0.1132849}
# Predicted option: A
# Answer precited: "In the library,"
#
# Predicted answer string: "give me a cup of tea"
# Correct option is B
# Probabilities for this question: {'A': 0.34624156, 'B': 0.34624156, 'C': 0.0}
# Predicted option: A
# Answer precited: "At a shop"
#
# Predicted answer string: "it"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "lt's not as good as it was."
#
# Predicted answer string: "i can ' t stand the terrible smoke inside"
# Correct option is B
# Probabilities for this question: {'A': 0.05328198, 'B': 0.4504001, 'C': 0.05328198}
# Predicted option: B
# Answer precited: "Because she doesn't like the smell of smoke inside."
#
# Predicted answer string: "spiders"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "Animals."
#
# Predicted answer string: "german"
# Correct option is B
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "German."
#
# Predicted answer string: "you can pay me back soon"
# Correct option is A
# Probabilities for this question: {'A': 0.9381454, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "Yes, he can."
#
# Predicted answer string: "start off at 2 o ' clock"
# Correct option is A
# Probabilities for this question: {'A': 0.2854531, 'B': 0.3420958, 'C': 0.0}
# Predicted option: B
# Answer precited: "Go there 2 hours earlier."
#
# Predicted answer string: "october 24th , united nations day"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 1.0}
# Predicted option: C
# Answer precited: "October 24th."
#
# Predicted answer string: "men : may i see your air ticket and passport"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "At the police station."
#
# Predicted answer string: "new music record"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0}
# Predicted option: B
# Answer precited: "A record."
#
# Predicted answer string: "he ' s now living in a quieter place"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.7745967, 'C': 0.0}
# Predicted option: B
# Answer precited: "To live in a quiet place."
#
# Predicted answer string: "8 pounds"
# Correct option is B
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "8 pounds."
#
# Predicted answer string: "i must stay in and write an important essay"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.57735026, 'C': 0.0}
# Predicted option: B
# Answer precited: "Stay at home."
#
# Predicted answer string: "people say the manager doesn ' t like young people with long hair"
# Correct option is A
# Probabilities for this question: {'A': 0.37705922, 'B': 0.6696395, 'C': 0.024668736}
# Predicted option: B
# Answer precited: "He doesn't like young people."
#
# Predicted answer string: "what happened"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: B
# Answer precited: "Kevin made up stories about her."
#
# Predicted answer string: "a new epidemic called sars is threatening us right now ."
# Correct option is A
# Probabilities for this question: {'A': 0.14736396, 'B': 0.1355938, 'C': 0.0}
# Predicted option: A
# Answer precited: "She is following instructions not to use the air-conditioning."
#
# Predicted answer string: "woman"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "Friends."
#
# Predicted answer string: "go along this road , then you ' ll find it before the supermarket"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0}
# Predicted option: B
# Answer precited: "Before the supermarket."
#
# Predicted answer string: "its reports are serious and it tells us the truth"
# Correct option is C
# Probabilities for this question: {'A': 0.06818661, 'B': 0.06818661, 'C': 0.84700996}
# Predicted option: C
# Answer precited: "Its reports are true."
#
# Predicted answer string: "today i have to practice driving"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.44124368, 'C': 0.0}
# Predicted option: B
# Answer precited: "She has to prepare for a driving competition."
#
# Predicted answer string: "four"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: B
# Answer precited: "3."
#
# Predicted answer string: "week"
# Correct option is A
# Probabilities for this question: {'A': 0.4082483, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "Not less than one time a week."
#
# Predicted answer string: "we saw police partners ii"
# Correct option is B
# Probabilities for this question: {'A': 0.2581989, 'B': 0.3333333, 'C': 0.3333333}
# Predicted option: B
# Answer precited: "She saw a movie."
#
# Predicted answer string: "almost three years"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.11988322, 'C': 1.0}
# Predicted option: C
# Answer precited: "Almost three years."
#
# Predicted answer string: "they are too old"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: B
# Answer precited: "Because they were worn out."
#
# Predicted answer string: "70 pounds"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "In a store."
#
# Predicted answer string: "helen ' s just the opposite ."
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "Helen is quiet."
#
# Predicted answer string: "they are sold out . woman : but we have a few left for tomorrow"
# Correct option is B
# Probabilities for this question: {'A': 0.08142496, 'B': 0.39609075, 'C': 0.70710677}
# Predicted option: C
# Answer precited: "There aren't any tickets left for tomorrow's show."
#
# Predicted answer string: "washington"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "They went to Beijing three days ago."
#
# Predicted answer string: "it ' s too noisy here"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "Because he didn't like listening to radio."
#
# Predicted answer string: "never mind"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "Mr. Lin won't fire the man."
#
# Predicted answer string: "take the bus"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 1.0}
# Predicted option: C
# Answer precited: "By bus."
#
# Predicted answer string: "extremely cool"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 1.0}
# Predicted option: C
# Answer precited: "Very cool."
#
# Predicted answer string: "[CLS] what is the woman ' s name ? [SEP] justin : uh , hi . do you need some help with those weights ? i can move them for you . rachel : uh , no . i can do it myself . i just have to put them back over there . justin : no , let me help you . uh , oh , hmpf . rachel : oh , it ' s okay . justin : oh , my back ! rachel : it ' s okay , it ' s okay . are you okay ? justin : i just need to lie down here . uh . do you come here often ? rachel : yeah . i usually come five times a week . justin : oh , oh man . by the way , my name ' s justin . rachel : i ' m rachel . justin : uh , so , where are you from ? rachel : i ' m originally from california . . . are you sure you ' re okay ? justin : ( said in agony ) yeah , um , i ' m okay . where are you from ? rachel : um , i spent most of my life in a small town in utah called spanish fork actually . justin : oh , um , i just need to lie here . rachel : um , so , where are you from , justin ? i ' m going to call the manager . justin : no , no , no , no , no ! i just need to rest . oh yeah , i ' m from , from , uh , from spanish fork . rachel : wait . are you sure ? you ' re just not thinking right . justin : no , no , no . not spanish . . . . ah , no , i ' m from salt lake city . so , what do you do for a living anyway ? are you a body builder or something ? rachel : no , no . i ' m a teacher"
# Correct option is C
# Probabilities for this question: {'A': 0.018588401, 'B': 0.22520359, 'C': 0.6867701}
# Predicted option: C
# Answer precited: "The woman's name is Rachel."
#
# Predicted answer string: "[CLS]"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "computer"
#
# Predicted answer string: "busy"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: B
# Answer precited: "It's like a struggle."
#
# Predicted answer string: "anna ' s friend"
# Correct option is A
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "Anna."
#
# Predicted answer string: "five times"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "320,000."
#
# Predicted answer string: "eight o ' clock this morning"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "At 8:00."
#
# Predicted answer string: "good activities ."
# Correct option is C
# Probabilities for this question: {'A': 0.37433988, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "They aren't very good because they're so different."
#
# Predicted answer string: "she"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: B
# Answer precited: "They are not likely to get help from Debbie."
#
# Predicted answer string: "i ' m sorry , i have made a plan"
# Correct option is A
# Probabilities for this question: {'A': 0.78177196, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "She has already made her plan."
#
# Predicted answer string: "an opportunity than a threat"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.334198, 'C': 0.0}
# Predicted option: B
# Answer precited: "It can be seen as a model by the rest of the world."
#
# Predicted answer string: "three years ago"
# Correct option is A
# Probabilities for this question: {'A': 1.0, 'B': 0.0, 'C': 0.0}
# Predicted option: A
# Answer precited: "Three years ago."
#
# Predicted answer string: "men : i ' ve got a bad headache , and my nose is running ."
# Correct option is A
# Probabilities for this question: {'A': 0.25251475, 'B': 0.25251475, 'C': 0.0}
# Predicted option: A
# Answer precited: "Doctor and patient."
#
# Predicted answer string: "7 o ' clock"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: B
# Answer precited: "At 5:30"
#
# Predicted answer string: "try later"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "Go into the man's office."
#
# Predicted answer string: "75"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0}
# Predicted option: B
# Answer precited: "75."
#
# Predicted answer string: "we are out of them now"
# Correct option is C
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: A
# Answer precited: "The man is looking for a smaller shirt."
#
# Predicted answer string: "the shots i took are as good as i thought"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.4472136}
# Predicted option: C
# Answer precited: "What the man thinks of the shots."
#
# Predicted answer string: "two days"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: B
# Answer precited: "For 3 days."
#
# Predicted answer string: "too small and not in proper condition"
# Correct option is C
# Probabilities for this question: {'A': 0.03022778, 'B': 0.16517511, 'C': 0.78476095}
# Predicted option: C
# Answer precited: "It's small and not in good condition."
#
# Predicted answer string: "he ' s warm - hearted"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.0, 'C': 0.0}
# Random picked option: C
# Answer precited: "Bob wants money."
#
# Predicted answer string: "four years ago"
# Correct option is B
# Probabilities for this question: {'A': 0.0, 'B': 1.0, 'C': 0.0}
# Predicted option: B
# Answer precited: "Four years ago."
#
# Predicted answer string: "tomato , cheese , or chocolate"
# Correct option is C
# Probabilities for this question: {'A': 0.70710677, 'B': 0.70710677, 'C': 0.0}
# Predicted option: A
# Answer precited: "Tomato."
#
# Predicted answer string: "men : no , you mustn ' t drive on the right there"
# Correct option is A
# Probabilities for this question: {'A': 0.0, 'B': 0.07498121, 'C': 0.6393535}
# Predicted option: C
# Answer precited: "Whether to have the right to drive a car in England."
#
# Accuracy 0.45998445998445997
#               precision    recall  f1-score   support
#
#            A       0.41      0.46      0.43       392
#            B       0.46      0.49      0.47       437
#            C       0.51      0.44      0.47       458
#
#     accuracy                           0.46      1287
#    macro avg       0.46      0.46      0.46      1287
# weighted avg       0.46      0.46      0.46      1287
